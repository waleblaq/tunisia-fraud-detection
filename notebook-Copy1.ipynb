# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
color = sns.color_palette()

# %%
train = pd.read_csv('train (2).csv')
test = pd.read_csv('test (2).csv')
print('train size:', train.shape )
print('test size:', test.shape )
# Out:
# train size: (25053, 121)
# test size: (10738, 120)

# %%
train.head(10)
# Out:
#    BCT_CODBUR  CTR_MATFIS CTR_CATEGO_X  FJU_CODFJU  CTR_CESSAT  ACT_CODACT  \
# 0          49       14185            P          99           1        6101
# 1         221        6032            P          99           0        6271
# 2         181        8907            P          99           0        6102
# 3         252        5783            M          22           0        4403
# 4         234        1477            P          99           0        6312
# 5         136        8370            C          99           0        4410
# 6          35        1098            C          99           0        4809
# 7         408       13084            M          22           0        4755
# 8         122       13945            C          99           0        4204
# 9         216       10480            P          99           0        6308
#
#    CTR_OBLDIR  CTR_OBLACP  CTR_OBLRES  CTR_OBLFOP  ...     target  \
# 0           4           2           2           2  ...  13.575957
# ...

# %%
train.isnull().sum()
# Out:
# BCT_CODBUR          0
# CTR_MATFIS          0
# CTR_CATEGO_X        0
# FJU_CODFJU          0
# CTR_CESSAT          0
# ACT_CODACT          0
# CTR_OBLDIR          0
# CTR_OBLACP          0
# CTR_OBLRES          0
# CTR_OBLFOP          0
# CTR_OBLTFP          0
# CTR_OBLDCO          0
# CTR_OBLTVA          0
# CTR_OFODEC         10
# CTR_OFODEP         10
# CTR_OFODET         10
# CTR_OBLAUT         10
# CTR_OBLASS         10
# CTR_ODTIMB         10
# CTR_OBLTCL          0
# CTR_OBLTHO         10
# CTR_OBLDLI         10
# CTR_OBLTVI         10
# CTR_RATISS          0
# EXE_EXERCI          0
# TVA_CHAFF6       1974
# TVA_CHAFF7       1974
# TVA_CHAF10       1974
# TVA_CHAF12       1974
# TVA_CAF125       1974
#                 ...
# SND_MNTPRD_E    23610
# SND_MNTTVA_E    23610
# SND_MNTDRC_E    23610
# SND_MNTAVA_E    23610
# SND_MNTTAX_E    23610
# SND_MNTPAY_E    23610
# SND_MNTAIR_E    23610
# SND_MNTPRD_A    21631
# SND_MNTTVA_A    21631
# SND_MNTDRC_A    21631
# ...

# %%
ntrain = train.shape[0]
ntest = test.shape[0]
fulldata = pd.concat((train, test)).reset_index(drop = 'true')
print(ntrain , ntest, 'fulldata size:', fulldata.shape)
# Out:
# C:\Users\olugbenle enoch\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   This is separate from the ipykernel package so we can avoid doing imports until
# 25053 10738 fulldata size: (35791, 121)

# %%
fulldata.isnull().sum()
# Out:
# ACT_CODACT          0
# ADB_MNTORD      26767
# AX1_BRTIMP       8670
# AX2_HONORA       8670
# AX2_LOYERS       8670
# AX3_REVCAP       8670
# AX5_MNTMAR       8670
# BCT_CODBUR          0
# CTR_CATEGO_X        0
# CTR_CESSAT          0
# CTR_MATFIS          0
# CTR_OBLACP          0
# CTR_OBLASS         14
# CTR_OBLAUT         14
# CTR_OBLDCO          0
# CTR_OBLDIR          0
# CTR_OBLDLI         14
# CTR_OBLFOP          0
# CTR_OBLRES          0
# CTR_OBLTCL          0
# CTR_OBLTFP          0
# CTR_OBLTHO         14
# CTR_OBLTVA          0
# CTR_OBLTVI         14
# CTR_ODTIMB         14
# CTR_OFODEC         14
# CTR_OFODEP         14
# CTR_OFODET         14
# CTR_RATISS          0
# EXE_EXERCI          0
#                 ...
# TVA_CRDRES       2782
# TVA_CRDRMC       2782
# TVA_CRDRMP       2782
# TVA_DEDAUI       2782
# TVA_DEDAUL       2782
# TVA_DEDEQI       2782
# TVA_DEDEQL       2782
# TVA_DEDIMB       2782
# TVA_DEDREG       2782
# TVA_DEDRSM       2782
# ...

# %%
fulldata.drop(['TVA_CRDRES',       
'TVA_CRDRMC',      
'TVA_CRDRMP',       
'TVA_DEDAUI',       
'TVA_DEDAUL',       
'TVA_DEDEQI',       
'TVA_DEDEQL',       
'TVA_DEDIMB',       
'TVA_DEDREG',      
'TVA_DEDRSM',       
'TVA_MACHN',        
'TVA_MCESQ',        
'TVA_MNTPAY',       
'TVA_MOIDEB',       
'TVA_MOIFIN',       
'TVA_MTALSM',       
'TVA_MTDJRTAX',     
'TVA_MTDJRTVA',     
'TVA_MTORDTAX',     
'TVA_MTORDTVA',     
'TVA_MTRESTAX',     
'TVA_MTVLSM',       
'TVA_RESTIT',       
'TVA_RSNRES',       
'TVA_TOTDUE',       
'TVA_TRSPOR',       
'TVA_TXALSM',       
'TVA_TXVLSM',
'TVA_ACHNDD',      
'TVA_ACHSUS',       
'TVA_BASAUI',       
'TVA_BASAUL',       
'TVA_BASEQI',       
'TVA_BASEQL',       
'TVA_BASIMB',       
'TVA_BASRSM',       
'TVA_CA072018',     
'TVA_CA132018',     
'TVA_CA192018',     
'TVA_CAF125', 
'TVA_CAFEXO',       
'TVA_CAFEXP',       
'TVA_CAFSUS',       
'TVA_CHAF10',       
'TVA_CHAF12',       
'TVA_CHAF15',       
'TVA_CHAF18',       
'TVA_CHAF22',     
'TVA_CHAF29',       
'TVA_CHAF36',      
'TVA_CHAFF6',       
'TVA_CHAFF7',       
'TVA_CRDBLQ',       
'TVA_CRDFIN',       
'TVA_CRDINI',       
'TVA_CRDREP',
'SND_MNTAIR_A',    
'SND_MNTAIR_E',    
'SND_MNTAIR_I',    
'SND_MNTAVA_A',    
'SND_MNTAVA_E',    
'SND_MNTAVA_I',   
'SND_MNTDRC_A',    
'SND_MNTDRC_E',    
'SND_MNTDRC_I',    
'SND_MNTPAY_A',    
'SND_MNTPAY_E',    
'SND_MNTPAY_I',    
'SND_MNTPRD_A',    
'SND_MNTPRD_E',    
'SND_MNTPRD_I',    
'SND_MNTTAX_A',
'SND_MNTTAX_E',    
'SND_MNTTAX_I',    
'SND_MNTTVA_A',    
'SND_MNTTVA_E',    
'SND_MNTTVA_I',    
'TVA_AACHAB',  
'TVA_ACHEXO',      
'FAC_MNTPRI_F',    
'FAC_MNTTVA_C',    
'FAC_MNTTVA_F',    
'ADB_MNTORD',      
'AX1_BRTIMP',       
'AX2_HONORA',       
'AX2_LOYERS',       
'AX3_REVCAP',       
'AX5_MNTMAR',
'FAC_MFODEC_C',    
'FAC_MFODEC_F',    
'FAC_MNTDCO_C',    
'FAC_MNTDCO_F',    
'FAC_MNTPRI_C',              ], axis = 1, inplace = True)

# %%
fulldata.isnull().sum()
# Out:
# ACT_CODACT          0
# BCT_CODBUR          0
# CTR_CATEGO_X        0
# CTR_CESSAT          0
# CTR_MATFIS          0
# CTR_OBLACP          0
# CTR_OBLASS         14
# CTR_OBLAUT         14
# CTR_OBLDCO          0
# CTR_OBLDIR          0
# CTR_OBLDLI         14
# CTR_OBLFOP          0
# CTR_OBLRES          0
# CTR_OBLTCL          0
# CTR_OBLTFP          0
# CTR_OBLTHO         14
# CTR_OBLTVA          0
# CTR_OBLTVI         14
# CTR_ODTIMB         14
# CTR_OFODEC         14
# CTR_OFODEP         14
# CTR_OFODET         14
# CTR_RATISS          0
# EXE_EXERCI          0
# FJU_CODFJU          0
# RES_ANNIMP          0
# id                  0
# target          10738
# dtype: int64

# %%
fulldata.head()
# Out:
#    ACT_CODACT  BCT_CODBUR CTR_CATEGO_X  CTR_CESSAT  CTR_MATFIS  CTR_OBLACP  \
# 0        6101          49            P           1       14185           2
# 1        6271         221            P           0        6032           2
# 2        6102         181            P           0        8907           2
# 3        4403         252            M           0        5783           2
# 4        6312         234            P           0        1477           2
#
#    CTR_OBLASS  CTR_OBLAUT  CTR_OBLDCO  CTR_OBLDIR  ...  CTR_ODTIMB  \
# 0         1.0         1.0           1           4  ...         1.0
# 1         1.0         1.0           1           8  ...         1.0
# 2         1.0         1.0           1           4  ...         1.0
# 3         1.0         1.0           1           4  ...         2.0
# 4         1.0         1.0           1           8  ...         1.0
#
#    CTR_OFODEC  CTR_OFODEP  CTR_OFODET  CTR_RATISS  EXE_EXERCI  FJU_CODFJU  \
# ...

# %%
histogram_Value =fulldata.CTR_OBLASS.hist(bins =25, figsize=[14,10])

# %%
fulldata['CTR_OBLASS'].value_counts()
# Out:
# 1.0    35774
# 2.0        3
# Name: CTR_OBLASS, dtype: int64

# %%
fulldata['CTR_OBLASS'].fillna(1.0,  inplace = True)

# %%
histogram_Value =fulldata.CTR_OBLAUT.hist(bins =25, figsize=[14,10])

# %%
fulldata['CTR_OBLAUT'].fillna(1.0,  inplace = True)

# %%
histogram_Value =fulldata.CTR_OBLDLI.hist(bins =25, figsize=[14,10])

# %%
fulldata['CTR_OBLDLI'].fillna(1.0,  inplace = True)

# %%
fulldata['CTR_OBLTHO'].value_counts()
# Out:
# 1.0    35324
# 2.0      453
# Name: CTR_OBLTHO, dtype: int64

# %%
fulldata['CTR_OBLTHO'].fillna(1.0, inplace= True, axis = 0)

# %%
fulldata['CTR_OBLTVI'].fillna(1.0, inplace= True)
fulldata['CTR_ODTIMB'].fillna(1.0, inplace= True)
fulldata['CTR_OFODEC'].fillna(1.0, inplace= True)
fulldata['CTR_OFODEP'].fillna(1.0, inplace= True)
fulldata['CTR_OFODET'].fillna(1.0, inplace= True)

# %%
fulldata.isnull().sum()
# Out:
# ACT_CODACT          0
# BCT_CODBUR          0
# CTR_CATEGO_X        0
# CTR_CESSAT          0
# CTR_MATFIS          0
# CTR_OBLACP          0
# CTR_OBLASS          0
# CTR_OBLAUT          0
# CTR_OBLDCO          0
# CTR_OBLDIR          0
# CTR_OBLDLI          0
# CTR_OBLFOP          0
# CTR_OBLRES          0
# CTR_OBLTCL          0
# CTR_OBLTFP          0
# CTR_OBLTHO          0
# CTR_OBLTVA          0
# CTR_OBLTVI          0
# CTR_ODTIMB          0
# CTR_OFODEC          0
# CTR_OFODEP          0
# CTR_OFODET          0
# CTR_RATISS          0
# EXE_EXERCI          0
# FJU_CODFJU          0
# RES_ANNIMP          0
# id                  0
# target          10738
# dtype: int64

# %%
fulldata.head()
# Out:
#    ACT_CODACT  BCT_CODBUR CTR_CATEGO_X  CTR_CESSAT  CTR_MATFIS  CTR_OBLACP  \
# 0        6101          49            P           1       14185           2
# 1        6271         221            P           0        6032           2
# 2        6102         181            P           0        8907           2
# 3        4403         252            M           0        5783           2
# 4        6312         234            P           0        1477           2
#
#    CTR_OBLASS  CTR_OBLAUT  CTR_OBLDCO  CTR_OBLDIR  ...  CTR_ODTIMB  \
# 0         1.0         1.0           1           4  ...         1.0
# 1         1.0         1.0           1           8  ...         1.0
# 2         1.0         1.0           1           4  ...         1.0
# 3         1.0         1.0           1           4  ...         2.0
# 4         1.0         1.0           1           8  ...         1.0
#
#    CTR_OFODEC  CTR_OFODEP  CTR_OFODET  CTR_RATISS  EXE_EXERCI  FJU_CODFJU  \
# ...

# %%
hist_age = fulldata.ACT_CODACT.hist(bins=25,figsize=[15,10])

# %%
fulldata['CTR_CATEGO_X'].value_counts()
# Out:
# M    18431
# C     9642
# P     7707
# N       11
# Name: CTR_CATEGO_X, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder_fulldata = LabelEncoder()
fulldata['CTR_CATEGO_X'] = labelencoder_fulldata.fit_transform(fulldata['CTR_CATEGO_X'])

# %%
dc = pd.get_dummies(fulldata['CTR_CATEGO_X'], prefix = 'CTR_CATEGO_')

# %%
fulldata = pd.concat((fulldata, dc), axis = 1).reset_index(drop = 'true')

# %%
fulldata.corr() 
plt.figure(figsize=(50,20)) 
sns.heatmap(fulldata.corr(),annot=True)

# %%
fulldata.head()
# Out:
#    ACT_CODACT  BCT_CODBUR  CTR_CATEGO_X  CTR_CESSAT  CTR_MATFIS  CTR_OBLACP  \
# 0        6101          49             3           1       14185           2
# 1        6271         221             3           0        6032           2
# 2        6102         181             3           0        8907           2
# 3        4403         252             1           0        5783           2
# 4        6312         234             3           0        1477           2
#
#    CTR_OBLASS  CTR_OBLAUT  CTR_OBLDCO  CTR_OBLDIR  ...  CTR_CATEGO__2  \
# 0         1.0         1.0           1           4  ...              0
# 1         1.0         1.0           1           8  ...              0
# 2         1.0         1.0           1           4  ...              0
# 3         1.0         1.0           1           4  ...              0
# 4         1.0         1.0           1           8  ...              0
#
#    CTR_CATEGO__3  bct_codbur  eju_codfju  ctr_matfis  act_codact  \
# ...

# %%
fulldata.columns
# Out:
# Index(['ACT_CODACT', 'BCT_CODBUR', 'CTR_CATEGO_X', 'CTR_CESSAT', 'CTR_MATFIS',
#        'CTR_OBLACP', 'CTR_OBLASS', 'CTR_OBLAUT', 'CTR_OBLDCO', 'CTR_OBLDIR',
#        'CTR_OBLDLI', 'CTR_OBLFOP', 'CTR_OBLRES', 'CTR_OBLTCL', 'CTR_OBLTFP',
#        'CTR_OBLTHO', 'CTR_OBLTVA', 'CTR_OBLTVI', 'CTR_ODTIMB', 'CTR_OFODEC',
#        'CTR_OFODEP', 'CTR_OFODET', 'CTR_RATISS', 'EXE_EXERCI', 'FJU_CODFJU',
#        'RES_ANNIMP', 'id', 'target', 'CTR_CATEGO__0', 'CTR_CATEGO__1',
#        'CTR_CATEGO__2', 'CTR_CATEGO__3', 'bct_codbur', 'eju_codfju',
#        'ctr_matfis', 'act_codact', 'FJU_CODFJU_bin', 'BCT_CODBUR_bin',
#        'CTR_MATFIS_bin', 'ACT_CODACT_bin'],
#       dtype='object')

# %% [markdown]
# fulldata[['CTR_OBLDLI', 'CTR_OBLFOP', 'CTR_OBLRES', 'CTR_OBLTCL', 'CTR_OBLTFP',
#        'CTR_OBLTHO', 'CTR_OBLTVA', 'CTR_OBLTVI', 'CTR_ODTIMB', 'CTR_OFODEC',
#        'CTR_OFODEP', 'CTR_OFODET', 'CTR_RATISS', 'EXE_EXERCI',]]

# %%
hist_age = fulldata.BCT_CODBUR.hist(bins=25,figsize=[15,10])

# %%
(fulldata.ACT_CODACT**(1/4)).hist()

# %%
import pylab
import scipy.stats as stats
stats.probplot(fulldata.BCT_CODBUR, dist="norm", plot=pylab)
pylab.show()

# %%
stats.probplot(fulldata.ACT_CODACT**(1/4), dist="norm", plot=pylab)
pylab.show()

# %%
fulldata['bct_codbur'] = fulldata.BCT_CODBUR**(1/4)
fulldata['eju_codfju'] = fulldata.FJU_CODFJU**(1/4)
fulldata['ctr_matfis'] = fulldata.CTR_MATFIS**(1/4)
fulldata['act_codact'] = fulldata.ACT_CODACT**(1/4)

# %%
fulldata['FJU_CODFJU_bin'] = np.array(np.floor(np.array(fulldata['FJU_CODFJU']) / 10.))

# %% [markdown]
# import datetime
# fulldata['date_RES_ANNIMP'] = pd.to_datetime(fulldata['RES_ANNIMP'], format = '%y')

# %%
fulldata['BCT_CODBUR_bin'] = np.array(np.floor(np.array(fulldata['BCT_CODBUR']) / 100.))
fulldata['CTR_MATFIS_bin'] = np.array(np.floor(np.array(fulldata['CTR_MATFIS']) / 1000.))
fulldata['ACT_CODACT_bin'] = np.array(np.floor(np.array(fulldata['ACT_CODACT']) / 1000.))

# %%
ready_train = fulldata[:ntrain]
ready_test = fulldata[ntrain:]

# %%
X= ready_train.drop(['id', 'target', 'BCT_CODBUR', 'CTR_MATFIS', 'ACT_CODACT', 'FJU_CODFJU'], axis = 1)
y = ready_train['target']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
p = lr.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

rms = sqrt(mean_squared_error(y_test, p))
rms
# Out:
# 6.996131672309328

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor(n_estimators = 550)
rfr.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=550, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
pr = rfr.predict(X_test)

# %%
from sklearn.model_selection import KFold, cross_val_score
n_folds = 5
def rmsle_cv(model):
    kf = KFold(n_folds, shuffle=True, 
               random_state=42).get_n_splits(X.values)
    rmse= np.sqrt(-cross_val_score(model, X.values, y.values.ravel(), 
                  scoring="neg_mean_squared_error", cv = kf))
    return(rmse)

score = rmsle_cv(rfr)
print("Random Forest score: {:.3f} ({:.3f})\n".format(score.mean(), 
       score.std()))

# %%
#rfr.fit(X_train, y_train.ravel())
pre = rfr.predict(X_test)
#RF_pred = RF.predict(test1)

# %%
rfr.fit(X,y)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=550, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
import xgboost as xgb
xg_reg = xgb.XGBRegressor(objective ='reg:linear', colsample_bytree = 0.3, learning_rate = 0.3,
                max_depth = 5, alpha = 10, n_estimators = 700)
# Out:
# C:\Users\olugbenle enoch\Anaconda3\lib\site-packages\dask\config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}
# C:\Users\olugbenle enoch\Anaconda3\lib\site-packages\distributed\config.py:20: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   defaults = yaml.load(f)

# %%
xg_reg.fit(X_train,y_train)

preds = xg_reg.predict(X_test)
# Out:
# [06:54:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.0.0/src/objective/regression_obj.cu:167: reg:linear is now deprecated in favor of reg:squarederror.

# %%
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
params = {"objective":"reg:linear",'colsample_bytree': 0.3,'learning_rate': 0.5,
                'max_depth': 5, 'alpha': 10, 'n_estimators' : 550}

cv_results = xgb.cv(dtrain=data_dmatrix, params=params, nfold=50,
                    num_boost_round=1000,early_stopping_rounds=100,metrics="rmse", as_pandas=True, seed=123)
# Out:
# [01:56:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.0.0/src/objective/regression_obj.cu:167: reg:linear is now deprecated in favor of reg:squarederror.
# [01:56:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.0.0/src/objective/regression_obj.cu:167: reg:linear is now deprecated in favor of reg:squarederror.
# [01:56:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.0.0/src/objective/regression_obj.cu:167: reg:linear is now deprecated in favor of reg:squarederror.
# [01:56:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.0.0/src/objective/regression_obj.cu:167: reg:linear is now deprecated in favor of reg:squarederror.
# [01:56:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.0.0/src/objective/regression_obj.cu:167: reg:linear is now deprecated in favor of reg:squarederror.
# ...

# %%
cv_results.head()
# Out:
#    train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0         8.961734        0.001608        8.964269       0.121658
# 1         7.444789        0.034135        7.464878       0.093092
# 2         6.982236        0.050711        7.014840       0.121024
# 3         6.829599        0.050660        6.869060       0.142336
# 4         6.763846        0.046208        6.814755       0.158088

# %%
print((cv_results["test-rmse-mean"]).tail(1))
# Out:
# 999    6.200875
# Name: test-rmse-mean, dtype: float64

# %%
xg_reg = xgb.train(params=params, dtrain=data_dmatrix, num_boost_round=1000)
# Out:
# [05:46:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.0.0/src/objective/regression_obj.cu:167: reg:linear is now deprecated in favor of reg:squarederror.
# [05:46:38] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\learner.cc:328:
# Parameters: { n_estimators } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.

# %%
xgb.plot_importance(xg_reg)
plt.rcParams['figure.figsize'] = [20, 5]
plt.show()

# %%
submission = pd.read_csv('SampleSubmission (1).csv')

# %%
data_dmatrixt = xgb.DMatrix(data=ready_test.drop(['target', 'id'], axis=1))

# %%
predicted = rfr.predict(ready_test.drop(['target', 'id'], axis=1))

# %%
d = pd.DataFrame(predicted)

# %%
submission['target'] = d

# %%
submission.to_csv('togodbetheglory10.csv',index = False)
